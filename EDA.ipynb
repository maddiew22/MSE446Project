# %%
import pandas as pd
data = pd.read_csv("data/AABA_2006-01-01_to_2018-01-01.csv")
data.isna().sum()
data['High'].duplicated()
data['High'][3010:]
# Out:
# 3010    70.74
# 3011    70.36
# 3012    71.05
# 3013    72.17
# 3014    71.87
# 3015    71.39
# 3016    70.49
# 3017    70.32
# 3018    70.13
# Name: High, dtype: float64

# %%
data.plot(x='Date', y='High')
# Out:
# <Axes: xlabel='Date'>

# %%
all_stocks = pd.read_csv("data/all_stocks_2006-01-01_to_2018-01-01.csv")

print(all_stocks)
# Out:
#              Date   Open   High    Low  Close    Volume  Name
# 0      2006-01-03  77.76  79.35  77.24  79.11   3117200   MMM
# 1      2006-01-04  79.49  79.49  78.25  78.71   2558000   MMM
# 2      2006-01-05  78.41  78.65  77.56  77.99   2529500   MMM
# 3      2006-01-06  78.64  78.90  77.64  78.63   2479500   MMM
# 4      2006-01-09  78.50  79.83  78.46  79.02   1845600   MMM
# ...           ...    ...    ...    ...    ...       ...   ...
# 93607  2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 93608  2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 93609  2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 93610  2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 93611  2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [93612 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

all_stocks.set_index('Date').groupby('Name')['High'].plot(legend=True)
plt.xlabel('Date')
plt.ylabel('High')
plt.show()

# %%
all_stocks.isna().sum()
# Out:
# Date       0
# Open      25
# High      10
# Low       20
# Close      0
# Volume     0
# Name       0
# dtype: int64

# %% [markdown]
# Converting to datetime

# %%
data['Date'] = pd.to_datetime(data['Date'])
data = data.sort_values('Date')
data.set_index('Date', inplace = True)
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA
# ...           ...    ...    ...    ...       ...   ...
# 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 6 columns]

# %% [markdown]
# Select Relevant Years

# %%
valid_data = data[data['Date'] >='2010-01-01'].reset_index(drop=True)
valid_data
# Out:
#            Date   Open   High    Low  Close    Volume  Name
# 0    2010-01-04  16.94  17.20  16.88  17.10  16588957  AABA
# 1    2010-01-05  17.22  17.23  17.00  17.23  11718126  AABA
# 2    2010-01-06  17.17  17.30  17.07  17.17  16421960  AABA
# 3    2010-01-07  16.81  16.90  16.57  16.70  31816301  AABA
# 4    2010-01-08  16.68  16.76  16.62  16.70  15471074  AABA
# ...         ...    ...    ...    ...    ...       ...   ...
# 2007 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 2008 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 2009 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 2010 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 2011 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [2012 rows x 7 columns]
